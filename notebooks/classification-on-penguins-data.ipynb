# %% [markdown]
# * If you think my kernel is helpful, please give me a voteup. This is very important for new people like me. Thank you in advance.
# * If you have any question, please feel free to leave me a message, I will check every day. Thank you so much.

# %% [markdown]
# **Part I: Import library and load data**

# %%
# Data analysis libraries
import pandas as pd
import numpy as np

# Data visualization libraires
import seaborn as sns
import matplotlib.pyplot as plt

# show plot in the notebook
# %matplotlib inline

# Next, we'll load the penguins flower dataset, which is in the "../input/" directory
penguins = pd.read_csv("../data/penguins_lter.csv") # the penguins dataset is now a Pandas DataFrame

# %% [markdown]
# **Part II: Check the data information**

# %%
# first five observations
penguins.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
# Number of observations and missing values. 
# There are 150 observations and no nan value
penguins.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    str
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    str
#  3   Region               344 non-null    str
#  4   Island               344 non-null    str
#  5   Stage                344 non-null    str
#  6   Individual ID        344 non-null    str
#  7   Clutch Completion    344 non-null    str
#  8   Date Egg             344 non-null    str
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    str
#  14  Delta 15 N (o/oo)    330 non-null    float64
#  15  Delta 13 C (o/oo)    331 non-null    float64
#  16  Comments             26 non-null     str
# dtypes: float64(6), int64(1), str(10)
# memory usage: 45.8 KB

# %%
# Check basic description for features
penguins.drop(['Individual ID','Species', 'Sample Number'], axis=1).describe()
# Out:
#        Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# count          342.000000         342.000000           342.000000
# mean            43.921930          17.151170           200.915205
# std              5.459584           1.974793            14.061714
# min             32.100000          13.100000           172.000000
# 25%             39.225000          15.600000           190.000000
# 50%             44.450000          17.300000           197.000000
# 75%             48.500000          18.700000           213.000000
# max             59.600000          21.500000           231.000000
#
#        Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# count     342.000000         330.000000         331.000000
# mean     4201.754386           8.733382         -25.686292
# std       801.954536           0.551770           0.793961
# min      2700.000000           7.632200         -27.018540
# 25%      3550.000000           8.299890         -26.320305
# 50%      4050.000000           8.652405         -25.833520
# 75%      4750.000000           9.172123         -25.062050
# max      6300.000000          10.025440         -23.787670

# %%
# Check the response variable frequency
penguins['Species'].value_counts()
# Out:
# Species
# Adelie Penguin (Pygoscelis adeliae)          152
# Gentoo penguin (Pygoscelis papua)            124
# Chinstrap penguin (Pygoscelis antarctica)     68
# Name: count, dtype: int64

# %% [markdown]
# **Part III: Explorary data analysis**

# %%
# Create a pairplot of the data set. Which flower species seems to be the most separable?
sns.pairplot(penguins.drop(['Individual ID', 'Sample Number'], axis=1),hue='Species')
# penguins setosa seems most separable from the other two species

# %%
# Create a kde plot of sepal_length versus sepal width for setosa species of flower.
sub=penguins[penguins['Species']=='Adelie Penguin (Pygoscelis adeliae)']
sns.kdeplot(data=sub[['Culmen Length (mm)','Culmen Depth (mm)']])#,cmap="plasma", shade=True, shade_lowest=False)
plt.title('penguins-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
# Out:
# Text(0, 0.5, 'Sepal Width Cm')

# %%
sub=penguins[penguins['Species']=='Chinstrap penguin (Pygoscelis antarctica)']
sns.kdeplot(data=sub[['Culmen Length (mm)','Culmen Depth (mm)']])#,cmap="plasma", shade=True, shade_lowest=False)
plt.title('penguins-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
# Out:
# Text(0, 0.5, 'Sepal Width Cm')

# %%
sub=penguins[penguins['Species']=='Chinstrap penguin (Pygoscelis antarctica)']
sns.kdeplot(data=sub[['Culmen Length (mm)','Culmen Depth (mm)']])#,cmap="plasma", shade=True, shade_lowest=False)
plt.title('penguins-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
# Out:
# Text(0, 0.5, 'Sepal Width Cm')

# %%
penguins.drop(['studyName', 'Sex', 'Region', 'Island', 'Stage', 'Species', 'Clutch Completion', 'Date Egg', 'Individual ID', 'Sample Number', 'Comments'], axis=1)
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0                  39.1               18.7                181.0
# 1                  39.5               17.4                186.0
# 2                  40.3               18.0                195.0
# 3                   NaN                NaN                  NaN
# 4                  36.7               19.3                193.0
# ..                  ...                ...                  ...
# 339                 NaN                NaN                  NaN
# 340                46.8               14.3                215.0
# 341                50.4               15.7                222.0
# 342                45.2               14.8                212.0
# 343                49.9               16.1                213.0
#
#      Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 0           3750.0                NaN                NaN
# 1           3800.0            8.94956          -24.69454
# 2           3250.0            8.36821          -25.33302
# 3              NaN                NaN                NaN
# 4           3450.0            8.76651          -25.32426
# ..             ...                ...                ...
# 339            NaN                NaN                NaN
# 340         4850.0            8.41151          -26.13832
# 341         5750.0            8.30166          -26.04117
# 342         5200.0            8.24246          -26.11969
# 343         5400.0            8.36390          -26.15531
#
# [344 rows x 6 columns]

# %%
penguins.drop(['studyName', 'Sex', 'Region', 'Island', 'Stage', 'Species', 'Clutch Completion', 'Date Egg', 'Individual ID', 'Sample Number', 'Comments'], axis=1).dropna()
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 1                  39.5               17.4                186.0
# 2                  40.3               18.0                195.0
# 4                  36.7               19.3                193.0
# 5                  39.3               20.6                190.0
# 6                  38.9               17.8                181.0
# ..                  ...                ...                  ...
# 338                47.2               13.7                214.0
# 340                46.8               14.3                215.0
# 341                50.4               15.7                222.0
# 342                45.2               14.8                212.0
# 343                49.9               16.1                213.0
#
#      Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 1           3800.0            8.94956          -24.69454
# 2           3250.0            8.36821          -25.33302
# 4           3450.0            8.76651          -25.32426
# 5           3650.0            8.66496          -25.29805
# 6           3625.0            9.18718          -25.21799
# ..             ...                ...                ...
# 338         4925.0            7.99184          -26.20538
# 340         4850.0            8.41151          -26.13832
# 341         5750.0            8.30166          -26.04117
# 342         5200.0            8.24246          -26.11969
# 343         5400.0            8.36390          -26.15531
#
# [330 rows x 6 columns]

# %% [markdown]
# **Part 4: Train Test Split**

# %%
data_without_na = penguins
data_without_na.drop(['studyName', 'Sex', 'Region', 'Island', 'Stage', 'Clutch Completion', 'Date Egg', 'Individual ID', 'Sample Number', 'Comments'], axis=1).dropna()
# Out:
#                                  Species  Culmen Length (mm)  \
# 1    Adelie Penguin (Pygoscelis adeliae)                39.5
# 2    Adelie Penguin (Pygoscelis adeliae)                40.3
# 4    Adelie Penguin (Pygoscelis adeliae)                36.7
# 5    Adelie Penguin (Pygoscelis adeliae)                39.3
# 6    Adelie Penguin (Pygoscelis adeliae)                38.9
# ..                                   ...                 ...
# 338    Gentoo penguin (Pygoscelis papua)                47.2
# 340    Gentoo penguin (Pygoscelis papua)                46.8
# 341    Gentoo penguin (Pygoscelis papua)                50.4
# 342    Gentoo penguin (Pygoscelis papua)                45.2
# 343    Gentoo penguin (Pygoscelis papua)                49.9
#
#      Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# 1                 17.4                186.0         3800.0            8.94956
# 2                 18.0                195.0         3250.0            8.36821
# 4                 19.3                193.0         3450.0            8.76651
# 5                 20.6                190.0         3650.0            8.66496
# 6                 17.8                181.0         3625.0            9.18718
# ..                 ...                  ...            ...                ...
# 338               13.7                214.0         4925.0            7.99184
# 340               14.3                215.0         4850.0            8.41151
# 341               15.7                222.0         5750.0            8.30166
# 342               14.8                212.0         5200.0            8.24246
# 343               16.1                213.0         5400.0            8.36390
#
#      Delta 13 C (o/oo)
# 1            -24.69454
# 2            -25.33302
# 4            -25.32426
# 5            -25.29805
# 6            -25.21799
# ..                 ...
# 338          -26.20538
# 340          -26.13832
# 341          -26.04117
# 342          -26.11969
# 343          -26.15531
#
# [330 rows x 7 columns]

# %%
# Split data into a training set and a testing set.
# train_test_split shuffle the data before the split (shuffle=True by default)
from sklearn.model_selection import train_test_split
data_without_na = penguins
data_without_na = data_without_na.drop(['studyName', 'Sex', 'Region', 'Island', 'Stage', 'Clutch Completion', 'Date Egg', 'Individual ID', 'Sample Number', 'Comments'], axis=1).dropna()
X = data_without_na.drop(['Species'], axis=1)
y=data_without_na['Species']
  
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.5, shuffle=True,random_state=100)

# %%
X
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 1                  39.5               17.4                186.0
# 2                  40.3               18.0                195.0
# 4                  36.7               19.3                193.0
# 5                  39.3               20.6                190.0
# 6                  38.9               17.8                181.0
# ..                  ...                ...                  ...
# 338                47.2               13.7                214.0
# 340                46.8               14.3                215.0
# 341                50.4               15.7                222.0
# 342                45.2               14.8                212.0
# 343                49.9               16.1                213.0
#
#      Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 1           3800.0            8.94956          -24.69454
# 2           3250.0            8.36821          -25.33302
# 4           3450.0            8.76651          -25.32426
# 5           3650.0            8.66496          -25.29805
# 6           3625.0            9.18718          -25.21799
# ..             ...                ...                ...
# 338         4925.0            7.99184          -26.20538
# 340         4850.0            8.41151          -26.13832
# 341         5750.0            8.30166          -26.04117
# 342         5200.0            8.24246          -26.11969
# 343         5400.0            8.36390          -26.15531
#
# [330 rows x 6 columns]

# %%
y.unique()
# Out:
# <StringArray>
# [      'Adelie Penguin (Pygoscelis adeliae)',
#  'Chinstrap penguin (Pygoscelis antarctica)',
#          'Gentoo penguin (Pygoscelis papua)']
# Length: 3, dtype: str

# %% [markdown]
# **Part 5: Train a Model**
#
# For sklearn.svm.SVC(), The implementation is based on libsvm. The fit time complexity is more than quadratic with the number of samples which makes it hard to scale to dataset with more than a couple of 10000 samples. The multiclass support is handled according to a one-vs-one scheme.

# %%
# Now it's time to train a Support Vector Machine Classifier. 
# Call the SVC() model from sklearn and fit the model to the training data.
from sklearn.svm import SVC
model=SVC(C=500, kernel='rbf', tol=0.001, gamma=0.0001)
model.fit(X_train, y_train)
# Out:
# SVC(C=500, gamma=0.0001)

# %% [markdown]
# **Part 6: Model Evaluation**

# %%
# Now get predictions from the model and create a confusion matrix and a classification report.
pred=model.predict(X_test)
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
print(confusion_matrix(y_test, pred))
print('\n')
print(classification_report(y_test, pred))
print('\n')
print('Accuracy score is: ', accuracy_score(y_test, pred))
# Out:
# [[60  8  2]
#  [ 7 20  4]
#  [ 0  1 63]]
#
#
#                                            precision    recall  f1-score   support
#
#       Adelie Penguin (Pygoscelis adeliae)       0.90      0.86      0.88        70
# Chinstrap penguin (Pygoscelis antarctica)       0.69      0.65      0.67        31
#         Gentoo penguin (Pygoscelis papua)       0.91      0.98      0.95        64
#
#                                  accuracy                           0.87       165
#                                 macro avg       0.83      0.83      0.83       165
#                              weighted avg       0.86      0.87      0.86       165
#
#
#
# Accuracy score is:  0.8666666666666667

# %% [markdown]
# **Part 7: Gridsearch to tune hyperparameters**

# %%
penguins.head(20)
# Out:
#    studyName  Sample Number                              Species  Region  \
# 0    PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1    PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2    PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3    PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4    PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 5    PAL0708              6  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 6    PAL0708              7  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 7    PAL0708              8  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 8    PAL0708              9  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 9    PAL0708             10  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 10   PAL0708             11  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 11   PAL0708             12  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 12   PAL0708             13  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 13   PAL0708             14  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 14   PAL0708             15  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 15   PAL0708             16  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 16   PAL0708             17  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 17   PAL0708             18  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 18   PAL0708             19  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 19   PAL0708             20  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#        Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0   Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1   Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2   Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3   Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4   Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
# 5   Torgersen  Adult, 1 Egg Stage          N3A2               Yes  11/16/07
# 6   Torgersen  Adult, 1 Egg Stage          N4A1                No  11/15/07
# 7   Torgersen  Adult, 1 Egg Stage          N4A2                No  11/15/07
# 8   Torgersen  Adult, 1 Egg Stage          N5A1               Yes   11/9/07
# 9   Torgersen  Adult, 1 Egg Stage          N5A2               Yes   11/9/07
# 10  Torgersen  Adult, 1 Egg Stage          N6A1               Yes   11/9/07
# 11  Torgersen  Adult, 1 Egg Stage          N6A2               Yes   11/9/07
# 12  Torgersen  Adult, 1 Egg Stage          N7A1               Yes  11/15/07
# 13  Torgersen  Adult, 1 Egg Stage          N7A2               Yes  11/15/07
# 14  Torgersen  Adult, 1 Egg Stage          N8A1               Yes  11/16/07
# 15  Torgersen  Adult, 1 Egg Stage          N8A2               Yes  11/16/07
# 16  Torgersen  Adult, 1 Egg Stage          N9A1               Yes  11/12/07
# 17  Torgersen  Adult, 1 Egg Stage          N9A2               Yes  11/12/07
# 18  Torgersen  Adult, 1 Egg Stage         N10A1               Yes  11/16/07
# 19  Torgersen  Adult, 1 Egg Stage         N10A2               Yes  11/16/07
#
#     Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                 39.1               18.7                181.0         3750.0
# 1                 39.5               17.4                186.0         3800.0
# 2                 40.3               18.0                195.0         3250.0
# 3                  NaN                NaN                  NaN            NaN
# 4                 36.7               19.3                193.0         3450.0
# 5                 39.3               20.6                190.0         3650.0
# 6                 38.9               17.8                181.0         3625.0
# 7                 39.2               19.6                195.0         4675.0
# 8                 34.1               18.1                193.0         3475.0
# 9                 42.0               20.2                190.0         4250.0
# 10                37.8               17.1                186.0         3300.0
# 11                37.8               17.3                180.0         3700.0
# 12                41.1               17.6                182.0         3200.0
# 13                38.6               21.2                191.0         3800.0
# 14                34.6               21.1                198.0         4400.0
# 15                36.6               17.8                185.0         3700.0
# 16                38.7               19.0                195.0         3450.0
# 17                42.5               20.7                197.0         4500.0
# 18                34.4               18.4                184.0         3325.0
# 19                46.0               21.5                194.0         4200.0
#
#        Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0     MALE                NaN                NaN
# 1   FEMALE            8.94956          -24.69454
# 2   FEMALE            8.36821          -25.33302
# 3      NaN                NaN                NaN
# 4   FEMALE            8.76651          -25.32426
# 5     MALE            8.66496          -25.29805
# 6   FEMALE            9.18718          -25.21799
# 7     MALE            9.46060          -24.89958
# 8      NaN                NaN                NaN
# 9      NaN            9.13362          -25.09368
# 10     NaN            8.63243          -25.21315
# 11     NaN                NaN                NaN
# 12  FEMALE                NaN                NaN
# 13    MALE                NaN                NaN
# 14    MALE            8.55583          -25.22588
# 15  FEMALE                NaN                NaN
# 16  FEMALE            9.18528          -25.06691
# 17    MALE            8.67538          -25.13993
# 18  FEMALE            8.47827          -25.23319
# 19    MALE            9.11616          -24.77227
#
#                                  Comments
# 0          Not enough blood for isotopes.
# 1                                     NaN
# 2                                     NaN
# 3                      Adult not sampled.
# 4                                     NaN
# 5                                     NaN
# 6   Nest never observed with full clutch.
# 7   Nest never observed with full clutch.
# 8               No blood sample obtained.
# 9    No blood sample obtained for sexing.
# 10   No blood sample obtained for sexing.
# 11              No blood sample obtained.
# 12         Not enough blood for isotopes.
# 13         Not enough blood for isotopes.
# 14                                    NaN
# 15         Not enough blood for isotopes.
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN

# %% [markdown]
# ***  7.1 GridSearchCV does not shuffle the data before CV like train_test_split, we need to shuttle the penguins data by ourselves before using the GridSearchCV. Since in the original penguins data, data is sorted by species. ***

# %%
from sklearn.utils import shuffle
# X=penguins.drop('Species', axis=1)
# y=penguins['Species']
print('Before shuffle: ',y[0:20])
X,y = shuffle(X,y, random_state=0)
print("After shuffle: ", y[0:20])
# Out:
# Before shuffle:  234            Gentoo penguin (Pygoscelis papua)
# 77           Adelie Penguin (Pygoscelis adeliae)
# 144          Adelie Penguin (Pygoscelis adeliae)
# 343            Gentoo penguin (Pygoscelis papua)
# 81           Adelie Penguin (Pygoscelis adeliae)
# 87           Adelie Penguin (Pygoscelis adeliae)
# 114          Adelie Penguin (Pygoscelis adeliae)
# 96           Adelie Penguin (Pygoscelis adeliae)
# 104          Adelie Penguin (Pygoscelis adeliae)
# 20           Adelie Penguin (Pygoscelis adeliae)
# 110          Adelie Penguin (Pygoscelis adeliae)
# 328            Gentoo penguin (Pygoscelis papua)
# 176    Chinstrap penguin (Pygoscelis antarctica)
# 147          Adelie Penguin (Pygoscelis adeliae)
# 299            Gentoo penguin (Pygoscelis papua)
# 161    Chinstrap penguin (Pygoscelis antarctica)
# 168    Chinstrap penguin (Pygoscelis antarctica)
# 166    Chinstrap penguin (Pygoscelis antarctica)
# 320            Gentoo penguin (Pygoscelis papua)
# 324            Gentoo penguin (Pygoscelis papua)
# Name: Species, dtype: str
# After shuffle:  54           Adelie Penguin (Pygoscelis adeliae)
# 2            Adelie Penguin (Pygoscelis adeliae)
# 55           Adelie Penguin (Pygoscelis adeliae)
# 183    Chinstrap penguin (Pygoscelis antarctica)
# 112          Adelie Penguin (Pygoscelis adeliae)
# 42           Adelie Penguin (Pygoscelis adeliae)
# 57           Adelie Penguin (Pygoscelis adeliae)
# 161    Chinstrap penguin (Pygoscelis antarctica)
# 117          Adelie Penguin (Pygoscelis adeliae)
# 79           Adelie Penguin (Pygoscelis adeliae)
# 229            Gentoo penguin (Pygoscelis papua)
# 99           Adelie Penguin (Pygoscelis adeliae)
# 242            Gentoo penguin (Pygoscelis papua)
# 246            Gentoo penguin (Pygoscelis papua)
# 174    Chinstrap penguin (Pygoscelis antarctica)
# 337            Gentoo penguin (Pygoscelis papua)
# 23           Adelie Penguin (Pygoscelis adeliae)
# 240            Gentoo penguin (Pygoscelis papua)
# 32           Adelie Penguin (Pygoscelis adeliae)
# 330            Gentoo penguin (Pygoscelis papua)
# Name: Species, dtype: str

# %%
# Create a dictionary called param_grid and fill out some parameters for C and gamma.
param_grid = {'C': [0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']}
# param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': ['auto'], 'kernel': ['rbf']}
from sklearn.model_selection import GridSearchCV
grid=GridSearchCV(estimator=SVC(), param_grid=param_grid, scoring='accuracy',cv=3, verbose=1, refit=True )
grid.fit(X, y)
# Out:
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid={'C': [0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              scoring='accuracy', verbose=1)

# %% [markdown]
# * The GridSearchCV exhaustive search over specified parameter values for an estimator in param_grid.
# * CV=3 means we will use the three-fold cross-validation and check the performance of the mean accuracy score on the validation set (default is cv=3, three-fold cross-validation)
# * scoring='accuracy' means we choose parameters with the best accuracy score, this is the default setting. We can also use scoring='precision', 'f1', 'recall'
# * By using GridSearchCV to tune hyperparameters, we get 98.6% test accuracy score.

# %%
# The best hyperparameters chosen is
print(grid.best_params_)
print(grid.best_estimator_)
print('Mean cross-validated score of the best_estimator: ', grid.best_score_)
print('The number of cross-validation splits (folds/iterations): ', grid.n_splits_)
# Out:
# {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# SVC(C=100, gamma=0.0001)
# Mean cross-validated score of the best_estimator:  0.890909090909091
# The number of cross-validation splits (folds/iterations):  3

# %%
# Another optition for shuffle is to use cv=KFold, we get 98% accuracy
from sklearn.model_selection import KFold
# X=penguins.drop(['Species', 'Id'], axis=1)
# y=penguins['Species']
# Create a dictionary called param_grid and fill out some parameters for C and gamma.
param_grid = {'C': [0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']}
# param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': ['auto'], 'kernel': ['rbf']}
from sklearn.model_selection import GridSearchCV
grid=GridSearchCV(estimator=SVC(), param_grid=param_grid, scoring='accuracy',
                  cv=KFold(n_splits=3, shuffle=True, random_state=0), verbose=1, refit=True )
grid.fit(X, y)

# The best hyperparameters chosen is
print(grid.best_params_)
print(grid.best_estimator_)
print('Mean cross-validated score of the best_estimator: ', grid.best_score_)
print('The number of cross-validation splits (folds/iterations): ', grid.n_splits_)
# Out:
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# {'C': 500, 'gamma': 0.0001, 'kernel': 'rbf'}
# SVC(C=500, gamma=0.0001)
# Mean cross-validated score of the best_estimator:  0.9151515151515152
# The number of cross-validation splits (folds/iterations):  3
